# %%
import sys
sys.path.append('../')
from Models import LoadIntoDf

import numpy as np
import matplotlib.pyplot as plt

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_percentage_error, mean_absolute_error

# %%
# Load the data
df = LoadIntoDf.load_asc_count()
print('data loaded')
# Out:
# data loaded

# %%
df = df.sort_values(by='ascensionist_count')

# %%
df
# Out:
#       ascensionist_count  count(*)
# 0                      1     71774
# 1                      2     33222
# 2                      3     17639
# 3                      4      9453
# 4                      5      6349
# ...                  ...       ...
# 1948               28106         1
# 1949               31123         1
# 1950               31173         1
# 1951               35026         1
# 1952               36708         1
#
# [1953 rows x 2 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['ascensionist_count'], df['count(*)'], linewidth=.8)
plt.title('Ascensionist Counts')
plt.xlabel('Ascensionist Count')
plt.ylabel('Number of routes')

plt.grid(True)
plt.savefig('ascensionist_count.pdf', bbox_inches='tight') 
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['ascensionist_count'], df['count(*)'], linewidth=.8)
plt.title('Ascensionist Counts')
plt.xlabel('Ascensionist Count')
plt.ylabel('Number of routes')
plt.xscale('log')

plt.grid(True)
plt.savefig('ascensionist_count2.pdf', bbox_inches='tight') 
plt.savefig('ascensionist_count2.png', bbox_inches='tight') 
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['ascensionist_count'], df['count(*)'], linewidth=.8)
plt.title('Ascensionist Counts')
plt.xlabel('Ascensionist Count')
plt.ylabel('Number of routes')
plt.xscale('log')
plt.yscale('log')

plt.grid(True)
plt.savefig('ascensionist_count3.pdf', bbox_inches='tight') 
plt.savefig('ascensionist_count3.png', bbox_inches='tight') 
plt.show()

# %%
# Load the data
df = LoadIntoDf.load_sqlite_data('../')
print('data loaded')
# Out:
# data loaded

# %%
import matplotlib.pyplot as plt
text_counts = df['difficulty'].value_counts()
text_counts.index = text_counts.index.str.split('/').str[0]

text_counts = text_counts.sort_index()

# Plot the histogram

plt.bar(text_counts.index, text_counts.values)
plt.ylabel('Frequency')
plt.title('difficulty')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.savefig('histogram_difficulties.pdf', bbox_inches='tight')
plt.savefig('histogram_difficulties.png', bbox_inches='tight')
plt.show()
